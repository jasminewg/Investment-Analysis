# %% [markdown]
# Purpose of this project is to analyze technical indicators of all tech stocks with at least 100 million market capiptaliztion listed on multiple exchanges (NASDAQ, TSX, VSX).

# %%
# import a list of nasdap tech stocks
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup as bs
import fix_yahoo_finance as yf
import datetime

colnames = ['Symbol', 'Name','Last Sale','Net Change', 'Change', 'Market Cap','Country','IPO Year','Volume','Sector','Industry']

nasdaq_tech = pd.read_csv("nasdaq_tech.csv", names = colnames)
nasdaq_li = nasdaq_tech['Symbol'][1:]
nasdaq_tech.columns
# Out:
# C:\Users\Jasmi\Anaconda\lib\site-packages\fix_yahoo_finance\__init__.py:0: DeprecationWarning:
#
# *** `fix_yahoo_finance` was renamed to `yfinance`. ***
# Please install and use `yfinance` directly using `pip install yfinance -U`
#
# More information: https://github.com/ranaroussi/yfinance
# Index(['Symbol', 'Name', 'Last Sale', 'Net Change', 'Change', 'Market Cap',
#        'Country', 'IPO Year', 'Volume', 'Sector', 'Industry'],
#       dtype='object')

# %%
# import a list of TSX and Vancouver tech stocks. Combine into one list of symbols
tsx_tech = pd.read_excel('TSX tech.xlsx', sheet_name = [1,2])
tsx_li = tsx_tech[1]['Root\nTicker']
van_li = tsx_tech[2]['Root\nTicker'] + '.v'
stock_li = nasdaq_li.append(tsx_li).append(van_li)
stock_li
# Out:
# 1       AAPL
# 2       MSFT
# 3       GOOG
# 4      GOOGL
# 5         FB
#        ...
# 156    AST.v
# 157    DXX.v
# 158    EQG.v
# 159    DAR.v
# 160    LTX.v
# Length: 839, dtype: object

# %%
# import historical prices from file with previously downloaded data or from Yahoo Finance if file doesn't exist. 
# If imported from file, add most recent prices to data for updated analysis.
# This eliminates process of redownloading if program has to be restarted

import os.path
from datetime import timedelta

price = 'C:/Users/Jasmi/OneDrive/Documents/Stock Analysis/price.csv'
starttime = datetime.datetime(2015,1,1)
endtime = datetime.date.today()
final_price = pd.DataFrame()

def stock_download():
    try:
        stock = []
        stock = yf.download(symbol, starttime, endtime)
        if len(stock) == 0:
            None
        else:
            stock['Ticker'] = symbol
            final_price = final_price.append(stock)   
    except Exception:
        None

if os.path.exists(price):
    final_price = pd.read_csv(price)
    start = price_df.index.max() + delta(1)
    new_price = []
    for symbol in stock_li:
        if symbol in final_price['Ticker'].unique():
            new_price = yf.downlaod(symbol, start, endtime)
            new_price['Ticker'] = symbol
            final_price = final_price.append(new_price)
        else: 
            stock_download()
        
else:
# not every stock can be downloaded. use try and except to handle
    for symbol in stock_li:   
        stock_download()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ...

# %%
final_price
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for symbol in li:
    text = requests.get('https://stockcharts.com/h-sc/ui?s=' + symbol).text
    soup = bs(text)

# %%
# Use only Adjusted Closing price 
adj_price ={}
for symbol in stock_li:
    adj_price[symbol] = stock_price[symbol]['Adj Close']
adj_price

# %%
price_df = pd.DataFrame(adj_price)
price_df.to_csv(c'C:\Users\Jasmi\OneDrive\Documents\Stock Analysis\price')
price_df.head(20)

# %%
# compute MA for all stocks
ma_days = 10
ma_df = price_df.rolling(ma_days).mean()
ma_df.head(20)

# %%
# compute WMA 
weights = np.arange(1, ma_days+1)
wma_df = price_df.rolling(ma_days).apply(lambda x: np.dot(x, weights)/weights.sum())
wma_df.head(20)

# %%
# compute EMA using custom function
alpha = 2/(ma_days+1)
for i in len(price_df.index): 
    ewa[i] = alpha * price + (1 - alpha) * ewa(i - 1)
ewa_df = price_df.rolling(ma_days).apply(lambda x: )

# %%
# compute EMA using ewm function 
# emw 
ewa_df2 = price_df.ewm(span=ma_days).mean()
ewa_df2.head(20)

# %%
# Graph SMA, WMA, EMA for a stock of user's choice
import matplotlib as mpl
ticker = input("Enter a symbol:")
ticker.plot(price_df.ticker)

# %%
# ADX
ewa_df3 = 
ewa_df3

# %%
# compute MACD. use 9-day MACD as the signal line
long_ewa_days = 26
long_ewa = price_df.ewm(span=long_ewa_days).mean()
macd = ewa_df - long_ewa
sigal_days = 9
signal = macd.ewm(span=signal_days).mean()

# %%
# Stochastics

# %%
# RSI

# %%
# ROC

# %%
# Graph ADX, MACD, Stochastics, RSI, ROC for a stock

# %%
# Determine which stocks are oversold based on technical indicators. 
# If ADX is below 25 or in a downtrend, and Stochastics is close to zero, return these stocks
# IF ADX is in a uptrend, Stochastics and MACD are close to zero, return these stocks

# %%
# Examine correlations between individal stocks. Stocks in the same industry are expected to have strong positive 
# correlations, if there are stocks that exhibit strong negative correaltions, then investor diverting more weight
# of a portfolio into one industry can diversify some risks by choosing negative correlated combinations
corr = price_df.corr().unstack().sort_values()
corr[corr < - 0.9]
#corr.index[i][0] == corr.index[i+1][1]

# %%
corr_df.apply(lambda x: x.sort_values())

# %%
start = datetime.datetime(2021,1,1)
end = datetime.date.today()
test = yf.download("AAPL", start, end)
test.to_csv()
test
